# %%
# !sudo apt-get install python3-dev default-libmysqlclient-dev
# !pip install pymysql
# Out:
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# ...

# %%
import pandas as pd
import numpy as np
import pymysql

# %%
YtbInput = pd.read_csv('./file/YtbInput.csv', encoding='utf-8')
YtbInput
# Out:
#      Unnamed: 0                                              title  \
# 0             0                  절대 돈 안 잃는 재테크 3가지, 부자들은 꼭 하는 투자방법
# 1             1  부업 아닌, 하루 5분 투자로 3개월 만에 500만원 돈 벌기! (수익 인증+실제 ...
# 2             2     20대 직장인 재테크. 돈 모으기 위한 현명한 방법. 저축률 높이는 종잣돈 재테크.
# 3             3  재택 부업으로 월 300만원 돈버는 현실적인 방법 BEST3 (직장인 투잡+집에서 ...
# 4             4  [ENG/JPN] 놀거 다 놀면서 돈💸모으는 이야기 하면서 같이 준비해요🍑 (돈 모...
# ..          ...                                                ...
# 488         488  단순한 생활: 마음과 방의 상태는 이어져 있다 (습관, 미니멀라이프, 정리정돈, 방...
# 489         489     포트폴리오에서 현금 비중은 몇 퍼센트가 적당할까요?​ㅣ부유한칼럼ㅣ그림영상 (ENG)
# 490         490  20대가 절약하면 무슨 재미로 살까? 돈 쓰지 않고 혼자 조용히 잘 노는 짠순이의 ...
# 491         491  글로벌 경제 전망, 지정학적 맥락을 함께 보라-신환종 FICC리서치센터장 NH투자증...
# 492         492    뉴욕증시, FOMC 공격적 긴축 우려에 혼조 (2022.06.15/뉴스투데이/MBC)
#
#                                                   thum  \
# 0    https://i.ytimg.com/vi/hZQs2_Gn5Io/hqdefault.j...
# ...

# %% [markdown]
# # 데이터 정제

# %%
YtbInput.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     493 non-null    object
#  1   thum      475 non-null    object
#  2   link      493 non-null    object
#  3   author    493 non-null    object
#  4   views     493 non-null    object
#  5   time      493 non-null    object
#  6   subtitle  478 non-null    object
# dtypes: object(7)
# memory usage: 27.1+ KB

# %%
#인덱스 제거
YtbInput = YtbInput.drop(['Unnamed: 0'], axis = 1)
# 결측치 제거
YtbInput = YtbInput.dropna()
# 인덱스 정렬
YtbInput = YtbInput.reset_index(drop = True)

# %%
YtbInput.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     463 non-null    object
#  1   thum      463 non-null    object
#  2   link      463 non-null    object
#  3   author    463 non-null    object
#  4   views     463 non-null    object
#  5   time      463 non-null    object
#  6   subtitle  463 non-null    object
# dtypes: object(7)
# memory usage: 25.4+ KB

# %%
YtbInput
# Out:
#                                                  title  \
# 0                    절대 돈 안 잃는 재테크 3가지, 부자들은 꼭 하는 투자방법
# 1    부업 아닌, 하루 5분 투자로 3개월 만에 500만원 돈 벌기! (수익 인증+실제 ...
# 2       20대 직장인 재테크. 돈 모으기 위한 현명한 방법. 저축률 높이는 종잣돈 재테크.
# 3    재택 부업으로 월 300만원 돈버는 현실적인 방법 BEST3 (직장인 투잡+집에서 ...
# 4    [ENG/JPN] 놀거 다 놀면서 돈💸모으는 이야기 하면서 같이 준비해요🍑 (돈 모...
# ..                                                 ...
# 458      의외로 유용한 3가지 재활용 아이디어/생활속 재활용 꿀팁/똑똑한 재활용 살림팁81
# 459  지금은 시장이 아닌 조급증과 싸워야 할 때-김학균 리서치센터장 신영증권| [성공예감...
# 460  [주식실패담] 20년 경험담, 돈을 쉬게 하세요｜년 단위로 손실 없이 수익을 보고 ...
# 461         서울 아파트 매매수급지수 6주 연속 하락세 / KBS  2022.06.17.
# 462                   [삼성전자] 이 가격대까지 무조건 줍줍 하세요!! 꼭꼭!!
#
#                                                   thum  \
# 0    https://i.ytimg.com/vi/hZQs2_Gn5Io/hqdefault.j...
# 1    https://i.ytimg.com/vi/LTGqoa91MQg/hqdefault.j...
# 2    https://i.ytimg.com/vi/90fhxh0rB-A/hq720.jpg?s...
# 3    https://i.ytimg.com/vi/Pjupk76vdR4/hq720.jpg?s...
# ...

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:794625@127.0.0.1/ytb?charset=utf8mb4")

# %%
conn = engine.connect()

# %%
YtbInput.to_sql("ytb", conn, if_exists='append',index=False)

# %%
conn.close()

# %%
import pymysql.cursors

# Connect to the database
connection = pymysql.connect(host='127.0.0.1',
                             user='root',
                             password='794625',
                             database='ytb',
                             charset = 'utf8',
                            )
curs = connection.cursorclass=pymysql.cursors.DictCursor


with connection:
  pass
    # with connection.cursor() as cursor:
    #     # Create a new record
    #     sql = "INSERT INTO `users` (`email`, `password`) VALUES (%s, %s)"
    #     cursor.execute(sql, ('webmaster@python.org', 'very-secret'))

    # # connection is not autocommit by default. So you must commit to save
    # # your changes.
    # connection.commit()

    # with connection.cursor() as cursor:
    #     # Read a single record
    #     sql = "SELECT `id`, `password` FROM `users` WHERE `email`=%s"
    #     cursor.execute(sql, ('webmaster@python.org',))
    #     result = cursor.fetchone()
    #     print(result)

# %% [markdown]
# # 테이블 새생성

# %%
sql = '''CREATE TABLE YtbInput( 
col_vriable1 int(15) not null comment 'tile' primary key, 
col_vriable2 varchar(500) null comment 'thum', 
col_vriable3 varchar(500) null comment 'link',
col_vriable4 varchar(500) null comment 'author',
col_vriable5 varchar(500) null comment 'views',
col_vriable6 varchar(500) null comment 'time',
col_vriable7 TEXT         null comment 'subtitle'
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_bin
AUTO_INCREMENT=1 ;
''' 
curs.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2520/2506949387.py in <module>
#      10 AUTO_INCREMENT=1 ;
#      11 '''
# ---> 12 curs.execute(sql)
#
# TypeError: execute() missing 1 required positional argument: 'query'

# %%
for index, row in YtbInput.iterrows():
    tu = ( row.tile, row.thum,	row.link,	row.author,	row.views,	row.time,	row.subtitle) 
    curs.execute("""INSERT IGNORE INTO Store_Seoul_Info (col_variable1, col_variable2, col_variable3) VALUES (%s,%s,%s)"""
    ,tu)

# %%
CREATE DATABASE ytb;
USE ytb;

CREATE TABLE member -- Playdata memeber 테이블
( num	INT UNSIGNED AUTO_INCREMENT NOT NULL PRIMARY KEY, -- 고유 순번(PK)
  name		CHAR(3) NOT NULL, -- 이름
  gender	ENUM('M', 'F') NOT NULL,
  mobile	char(13), -- 휴대폰 번호
  firstNum	CHAR(3), -- 휴대폰의 국번 010
  midNum 	CHAR(4), -- 휴대폰의 중간 4자리 번호
  lastNum 	CHAR(4), -- 휴대폰의 마지막 4자리 번호
  addr		CHAR(10), -- 주소
  addr1		CHAR(5), -- 시
  addr2		CHAR(5), -- 구
  email		CHAR(30), -- 이메일
  email1	char(10), -- 이메일 아이디
  email2	char(20), -- 계정 ex. naver.com
  major		char(10), -- 전공
  birthYear	INT -- 출생년도
);

# %%
LOAD DATA INFILE 'C:\Users\ad\sources\Final-project\file\results2_유튜브추출데이터.csv'
INTO TABLE ytb_input
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS
(title,thum,link,author,views,time,subtitle)
SET title = title,
 thum = thum,
 link = link,
 author = author,
 views =views ,
 time = time,
 subtitle = subtitle,
# Out:
#   File "C:\Users\ad\AppData\Local\Temp/ipykernel_2520/1641768532.py", line 1
#     LOAD DATA INFILE 'C:\Users\ad\sources\Final-project\file\results2_유튜브추출데이터.csv'
#          ^
# SyntaxError: invalid syntax
